# %%
from skimage import data

# %% [markdown]
# https://scikit-image.org/docs/dev/api/skimage.io.html

# %%
camera=data.camera()

# %%
type(camera)
# Out:
# numpy.ndarray

# %%
camera.shape
# Out:
# (512, 512)

# %%
camera.size
# Out:
# 262144

# %%
camera
# Out:
# array([[156, 157, 160, ..., 152, 152, 152],
#        [156, 157, 159, ..., 152, 152, 152],
#        [158, 157, 156, ..., 152, 152, 152],
#        ...,
#        [121, 123, 126, ..., 121, 113, 111],
#        [121, 123, 126, ..., 121, 113, 111],
#        [121, 123, 126, ..., 121, 113, 111]], dtype=uint8)

# %% [markdown]
# to read a image from your computer

# %%
import skimage.io

# %%
image = skimage.io.imread(fname="C:/Users/Anant/Downloads/Nature.jpg")

# %%
skimage.io.imshow(camera)

# %%
skimage.io.imshow(image)
